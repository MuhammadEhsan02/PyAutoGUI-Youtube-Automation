# %%
import pyautogui
import time

# Open new tab
pyautogui.moveTo(x=551, y=11, duration=1)
pyautogui.click()

# Go to YouTube
pyautogui.moveTo(x=178, y=52, duration=1)
pyautogui.click()

# Enter YouTube URL
pyautogui.write('youtube.com')
pyautogui.hotkey('enter')
time.sleep(3)

# Search for the channel
pyautogui.moveTo(x=414, y=99, duration=1)
pyautogui.click()

# Enter the channel name
pyautogui.write('It expert by sir qasim')
pyautogui.hotkey('enter')
time.sleep(2)

# Open the channel
pyautogui.moveTo(x=699, y=218, duration=2)
pyautogui.click()
time.sleep(1.5)

# Open the playlist
pyautogui.moveTo(x=670, y=499, duration=2)
pyautogui.click()
time.sleep(1.5)

# Select the playlist
pyautogui.moveTo(x=786, y=649, duration=2)
pyautogui.click()
time.sleep(1.5)

# Subscribe to the channel
pyautogui.moveTo(x=318, y=700, duration=2)
pyautogui.click()

# Like the first video
pyautogui.moveTo(x=547, y=701, duration=2)
pyautogui.click()

# Watch the second video
pyautogui.moveTo(x=159, y=608, duration=2)
pyautogui.click()

# Like the second video
pyautogui.moveTo(x=547, y=701, duration=2)
pyautogui.click()

# Watch the third video
pyautogui.moveTo(x=159, y=608, duration=2)
pyautogui.click()

# Like the third video
pyautogui.moveTo(x=565, y=632, duration=2)
pyautogui.click()

# Watch the fourth video
pyautogui.moveTo(x=147, y=538, duration=2)
pyautogui.click()

# Like the fourth video
pyautogui.moveTo(x=565, y=632, duration=2)
pyautogui.click()
